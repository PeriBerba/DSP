# %% [markdown]
# <a href="https://colab.research.google.com/github/PeriBerba/DSP/blob/main/DSP_MidtermProject_StardustCrusader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Digital Signal Processing
# ## Midterm Project
# ### Berba, Peri Julian
# ### Camay, Justin Anjelo
# ### Carino, Caryll Franz
# ### Carsula, Karlo Angelo

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import periodogram




##Temperature per day
oct_20 = [ 30.1, 30.1, 30, 30, 29.7, 31.1, 31, 30.6, 30.5, 30.4,
    30.5, 30.5, 30.3, 30.1, 29.8, 29.9, 29.5, 29.7, 30,
    30.6, 30, 30, 30.1, 30.3, 30.1, 30.3, 30.2, 30.7,
    31, 31.2, 31.1, 31.3, 31.3, 31.3, 31.4, 31.3, 31.4,
    31.1, 31, 30.9, 31]

oct_21 = [31.3, 31.3, 30.9, 30.3, 30.3, 29.5, 29.1, 29, 28.7, 28.7,
    28.7, 28.5, 28.4, 28.3, 28.2, 28.2, 28.1, 28.3, 28.3, 28.3,
    28.2, 28.2, 28.1, 28.2, 28.3, 28.2, 28.2, 28.1, 28.1, 29,
    29.2, 29.3, 29.4, 29.5, 29.5, 29.7, 29.2, 29.3, 29.4, 29.5,
    29.4, 29.1, 29.2, 29.3, 29.5, 29.5, 29.2, 29.6, 29.5, 29.3,
    29.6, 29.3, 29.5, 29.7, 29.8, 30, 30, 29.5, 29.4, 29.7,
    29.3, 29.3, 29.4, 29.3, 29.2, 29.1, 29.4, 29.3, 29.3, 29.3,
    29.1, 29.4, 29.2, 28.6, 28.5, 28.3, 28.3, 28.2, 27.9, 27.7,
    27.5, 27.5, 27.5, 27.5, 27.5, 27.5, 27.4, 27.2, 27.3, 27.2,
    27.2, 27.1]

oct_22 = [27, 27, 27, 27, 27, 26.9, 26.9, 26.9, 26.8, 26.7,
    26.7, 26.6, 26.7, 26.6, 26.6, 26.7, 26.7, 26.7, 26.7,
    26.7, 26.6, 26.6, 26.6, 26.6, 26.6, 26.6, 26.6, 26.8, 27.1,
    27.2, 27.2, 27.2, 27.3, 28.1, 28.5, 29.2, 29.4, 29.3,
    29.5, 29.8, 29.7, 30.3, 30.4, 30.4, 30.4, 30.4, 30.5,
    30.6, 30.8, 30.8, 30.8, 30.8, 30.2, 30.1, 30.3, 30.3, 31,
    31, 31, 30.9, 30.8, 30.9, 30.9, 30.8, 30.9, 30.9, 30.2,
    30, 30.3, 30.2, 29.9, 29.4, 29.7, 29.6, 29.7, 29.6, 29.6,
    29.5, 29.4, 29.4, 29.4, 29.4, 29.2, 29.2, 29.1, 29.4, 30.8,
    30.9, 30.8, 30.8, 30.7, 30.6, 30.6, 30.6, 28.9]

oct_23 = [28.3, 28.1, 27.9, 27.8, 27.6, 27.5, 27.4, 27.4, 27.2, 27,
    27, 27, 26.9, 26.8, 26.8, 26.7, 26.8, 26.7, 26.8, 26.7,
    26.7, 26.8, 26.8, 26.7, 26.7, 26.7, 26.7, 26.8, 26.8, 26.8,
    26.9, 26.9, 26.9, 26.8, 26.9, 26.9, 29.3, 29.5, 29.5, 30.6,
    30.6, 30.5, 30.6, 30.5, 30, 30, 30.2, 30.1, 30.3, 30.5,
    30.4, 30.5, 30.5, 30.3, 29.7, 29.5, 29.5, 29.4, 29.5, 29.5,
    29.5, 29.5, 29.5, 29.7, 30.3, 30.8, 30.7, 30.2, 30.2, 30.3,
    30.4, 30.3, 30, 30.5, 30.3, 30.3, 29.9, 29.5, 29.5, 29.5,
    29.3, 29.1, 29.1, 29.4, 29.6, 29.5, 29.2, 28.9, 27.6, 27.4,
    27.4, 27.1, 27]

oct_24 = [26.9, 26.8, 26.7, 26.6, 26.5, 26.5, 26.5, 26.4, 26.4, 26.3,
    26.2, 26.2, 26.3, 26.1, 26.1, 26.0, 26.0, 26.0, 26.0, 25.9,
    25.9, 26.0, 26.0, 26.0, 26.0, 25.8, 26.1, 26.4, 26.7, 26.6,
    26.7, 26.9, 27.0, 29.1, 29.0, 29.8, 29.9, 30.0, 30.7, 31.1,
    31.3, 31.3, 31.6, 31.4, 31.2, 31.2, 31.3, 31.4, 30.9, 30.5,
    30.3, 30.1, 30.1, 30.1, 30.0, 29.9, 29.9, 29.8, 29.8, 30.0,
    29.8, 29.7, 29.5, 29.5, 29.5, 29.5, 29.4, 29.5, 29.3, 29.2,
    29.1, 29.1, 29.1, 29.0, 28.9, 28.9, 28.3, 28.1, 27.7, 27.6,
    27.3, 27.5, 27.3, 27.2, 27.4, 27.3, 27.4]

oct_25 = [27.4, 27.3, 27.3, 27.3, 27.2, 27.2, 27.1, 27.2, 27.2, 27.2,
    27.1, 27.2, 27.2, 27.2, 27, 27.1, 27.1, 27.1, 27.1, 27.1,
    27.1, 27, 27, 27, 27, 27, 27, 27.1, 27.1, 27.1, 27.1,
    27.2, 27.2, 27.4, 27.4, 27.5, 27.9, 28.1, 28.3, 28.3, 28.3,
    28.5, 28.5, 28.7, 28.9, 29, 29, 29, 29.2, 29.1, 29.1,
    29.1, 29.2, 29.2, 29.4, 29.3, 29.3, 29.3, 29.3, 29.3,
    29, 29.7, 30.5, 30.5, 30.3, 30.3, 30.5, 30.7, 30.9, 31.2,
    31.5, 31.2, 31.5, 31.3, 31, 30.3, 30.3, 30.2, 30.2, 30,
    30, 30, 29.7, 29.9, 29.5, 29.4, 29.7, 29.7, 29.8, 29.6,
    29.6, 29.5, 29.4, 29.3, 29.4, 29.3]

oct_26 = [28.5, 28.3, 28.1, 28, 27.7, 27.6, 27.5, 27.5, 27.4, 27.4,
    27.3, 27.2, 27.2, 27.2, 27.2, 27.3, 27.2, 27.2, 27.2, 27.1,
    27.1, 27.1, 27.1, 27.1, 27, 27, 27, 27, 27.2, 27.2, 27.3,
    27.8, 28.3, 29, 29.4, 29.7, 29.9, 30.2, 30.4, 30, 30, 30,
    30.6, 30.4, 31, 31.3, 30.4, 30.3, 30.2, 30.3, 30.3, 30.3,
    30.4, 30.6, 30.6, 30.6, 30.6, 30.6, 30.5, 30.5, 30.4, 30.4,
    30.3, 30.3, 30.3, 30.4, 30.4, 30.4, 30.4, 30.3, 30.1, 30.1,
    30, 30, 30, 29.9, 29.9, 29.8, 29.7, 29.7, 29.7, 29.3, 29.3,
    29.5, 28.7, 29.9, 30, 30.2, 30.6, 30.7, 30.5, 30.5, 30, 30.3,
    30.5]

oct_27 = [ 30.5, 29.4, 29.1, 29, 28.7, 28.6, 28.6, 28.5, 28.5, 28.5,
    28.1, 28.4, 28.7, 28.7, 28.9, 29.1, 30.1, 31.6, 31.9, 32.4,
    32.6, 32.5, 32, 32.4, 31.9, 32.4, 33, 32.7, 33.2, 32.5,
    32.4, 32.5, 32.5, 32.5, 32.8, 31.9, 31.5, 31.1, 31.1, 31,
    31, 31, 31, 31.2, 31.1, 31, 30.9, 30.8, 30.6, 30.5, 30.5,
    30.3, 30.3, 30.1, 30, 30, 29.9, 29.9, 29.7, 29.7, 29.7,
    29.7, 29.5, 29.5, 29.5, 29.5, 29.4, 29.3, 29.3, 29.2, 27.8,
    28.9, 28.9, 28.9]

Oct20 = np.mean(oct_20)
average_Oct20 = np.mean(oct_20)
print('Average Temperature:', average_Oct20, '°C')

# Plot the temperature data
plt.plot(oct_20)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 20, 2023')
plt.show()

Oct21 = np.mean(oct_21)
average_Oct21 = np.mean(oct_21)
print('Average Temperature:', average_Oct21, '°C')

# Plot the temperature data
plt.plot(oct_21)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 21, 2023')
plt.show()

Oct22 = np.mean(oct_22)
average_Oct22 = np.mean(oct_22)
print('Average Temperature:', average_Oct22, '°C')


# Plot the temperature data
plt.plot(oct_20)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 22, 2023')
plt.show()

Oct23 = np.mean(oct_23)
average_Oct23 = np.mean(oct_23)
print('Average Temperature:', average_Oct23, '°C')

# Plot the temperature data
plt.plot(oct_23)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 23, 2023')
plt.show()

Oct24 = np.mean(oct_24)
average_Oct24 = np.mean(oct_24)
print('Average Temperature:', average_Oct24, '°C')

# Plot the temperature data
plt.plot(oct_24)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 24, 2023')
plt.show()

Oct25 = np.mean(oct_25)
average_Oct25 = np.mean(oct_25)
print('Average Temperature:', average_Oct25, '°C')

# Plot the temperature data
plt.plot(oct_25)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 25, 2023')
plt.show()

Oct26 = np.mean(oct_26)
average_Oct26 = np.mean(oct_26)
print('Average Temperature:', average_Oct26, '°C')

# Plot the temperature data
plt.plot(oct_26)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 26, 2023')
plt.show()

Oct27 = np.mean(oct_27)
average_Oct27 = np.mean(oct_27)
print('Average Temperature:', average_Oct27, '°C')


# Plot the temperature data
plt.plot(oct_27)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 27, 2023')
plt.show()


Oct28 = np.mean(oct_28)
average_Oct28 = np.mean(oct_28)
print('Average Temperature:', average_Oct28, '°C')

# Plot the temperature data
plt.plot(oct_28)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 28, 2023')
plt.show()


Oct29 = np.mean(oct_29)
average_Oct29 = np.mean(oct_29)
print('Average Temperature:', average_Oct29, '°C')

# Plot the temperature data
plt.plot(oct_29)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 29, 2023')
plt.show()

Oct30 = np.mean(oct_30)
average_Oct30 = np.mean(oct_30)
print('Average Temperature:', Oct30, '°C')

# Plot the temperature data
plt.plot(oct_30)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 30, 2023')
plt.show()

Oct31 = np.mean(oct_31)
average_Oct31 = np.mean(oct_31)
print('Average Temperature:', average_Oct31, '°C')

# Plot the temperature data
plt.plot(oct_31)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 31, 2023')
plt.show()

Nov1 = np.mean(nov_1)
average_Nov1 = np.mean(nov_1)
print('Average Temperature:', average_Nov1, '°C')

# Plot the temperature data
plt.plot(nov_1)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data November 1, 2023')
plt.show()

Nov4 = np.mean(nov_4)
average_Nov4 = np.mean(nov_4)
print('Average Temperature:', average_Nov4, '°C')

# Plot the temperature data
plt.plot(nov_4)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data November 4, 2023')
plt.show()


Nov5 = np.mean(nov_5)
average_Nov5 = np.mean(nov_5)
print('Average Temperature:', average_Nov5, '°C')
# Plot the temperature data
plt.plot(nov_5)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data November 5, 2023')
plt.show()






# Calculate average temperature
average_temperature = np.mean(temperature_data)
print('Average Temperature:', average_temperature, '°C')

# Plot the temperature data
plt.plot(temperature_data)
plt.xlabel('Data')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Data October 20 - November 5  2023')
plt.show()
# Out:
# Average Temperature: 30.521951219512196 °C
# Average Temperature: 28.86521739130435 °C
# Average Temperature: 28.96315789473684 °C
# Average Temperature: 28.66344086021505 °C
# Average Temperature: 28.30229885057472 °C
# Average Temperature: 28.708333333333332 °C
# Average Temperature: 29.209473684210526 °C
# Average Temperature: 29.890625 °C
# Average Temperature: 29.6557894736842 °C
# Average Temperature: 30.017894736842102 °C
# Average Temperature: 30.934375 °C
# Average Temperature: 29.34631578947369 °C
# Average Temperature: 27.15684210526316 °C
# Average Temperature: 31.265957446808507 °C
# Average Temperature: 29.03510638297873 °C
# Average Temperature: 29.290218209179834 °C

# %%
import numpy as np
from scipy.fft import fft
import matplotlib.pyplot as plt


# Calculate the Fast Fourier Transform (FFT) of the temperature data
fft_result = fft(temperature_data)

# Get the frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(temperature_data))

# Find the index of the maximum non-zero magnitude in the FFT result
fundamental_frequency_index = np.argmax(np.abs(fft_result[1:len(temperature_data)//2])) + 1

# Calculate the fundamental frequency in Hertz
fundamental_frequency_hz = abs(frequencies[fundamental_frequency_index])

print("Fundamental Frequency:", fundamental_frequency_hz, "Hz")

# Plot the FFT magnitude and highlight the fundamental frequency
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(temperature_data)
plt.title("Temperature Data")
plt.xlabel("Time")
plt.ylabel("Temperature")

plt.subplot(2, 1, 2)
plt.plot(frequencies[1:len(temperature_data)//2], np.abs(fft_result[1:len(temperature_data)//2]))
plt.title("FFT Magnitude")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

# Highlight the fundamental frequency
plt.axvline(fundamental_frequency_hz, color='r', linestyle='--', label=f'Fundamental Frequency: {fundamental_frequency_hz} Hz')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fundamental Frequency: 0.011393514460999125 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = np.mean(temperature_data)
median = np.median(temperature_data)
mode = np.argmax(np.bincount(temperature_data))
plt.hist(temperature_data, bins=20, alpha=0.5, color='blue', label='Data')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')
plt.axvline(median, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median}')
plt.axvline(mode, color='purple', linestyle='dashed', linewidth=2, label=f'Mode: {mode}')
plt.legend()
plt.title("Mean, Median, and Mode")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create a sample dataset with hourly temperature readings from Oct 20 to Nov 5
start_date = '2023-10-20'
end_date = '2023-11-05'
date_range = pd.date_range(start=start_date, end=end_date, freq='H')
hourly_temperatures = np.random.uniform(25, 35, len(date_range))
temperature_data = pd.Series(hourly_temperatures, index=date_range)
daily_mean_temperatures = temperature_data.resample('D').mean()

plt.figure(figsize=(12, 6))

# Plot hourly temperatures as points
plt.plot(temperature_data.index, temperature_data.values, marker='o', markersize=3, label='Hourly Temperature', linestyle='-', color='blue')

# Plot daily mean temperatures as a line
plt.plot(daily_mean_temperatures.index, daily_mean_temperatures.values, label='Daily Mean Temperature', linestyle='-', color='red')

plt.xlabel('Date')
plt.ylabel('Temperature (°F)')
plt.title('Hourly and Daily Mean Temperature')
plt.legend()
plt.grid()
plt.show()
